# %% [markdown]
# ## Install Ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.1/749.1 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 39.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 46.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 66.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/nvidia-cufft-cu12/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.9 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.1/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Run inference on 'bus.jpg'
results = model(['/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/images/test/000000008746.jpg'])  # results list
results[0].plot()[..., ::-1]
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 23.5MB/s]
# 0: 448x640 16 persons, 1 umbrella, 1 frisbee, 1 chair, 108.7ms
# Speed: 2.8ms preprocess, 108.7ms inference, 660.2ms postprocess per image at shape (1, 3, 448, 640)
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [118, 143,  78],
#         [112, 166,  91],
#         [138, 172,  62]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [ 56,  79,   1],
#         [ 74,  86,   0],
#         [ 85,  89,  12]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [ 89, 128,   3],
#         [111, 120,  13],
#         [125, 131,  43]],
#
#        ...,
#
#        [[155, 158, 147],
#         [164, 165, 160],
#         [183, 184, 179],
#         ...,
#         [ 49,  46,  27],
#         [ 54,  49,  29],
#         [ 53,  45,  34]],
#
#        [[185, 187, 174],
# ...

# %%
import glob
export_dir = '/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k'
print(len(glob.glob(export_dir+"/images/train/*")))
print(len(glob.glob(export_dir+"/images/val/*")))
print(len(glob.glob(export_dir+"/images/test/*")))
# Out:
# 7000
# 2000
# 1000

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k'

# !yolo detect train data='/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/dataset.yaml' model='yolov8n.pt' epochs=30 imgsz=640 save=True batch=16
# Out:
# /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset_10k
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/runs/detect/train4/confusion_matrix.png', width=600)

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k'

# !yolo task=segment mode=val model='/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/runs/detect/train4/weights/best.pt' data='/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/dataset.yaml'
# Out:
# /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset_10k
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 4.86MB/s]
# val: Scanning /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset_10k/labels/val.cache... 2000 images, 0 backgrounds, 0 corrupt: 100% 2000/2000 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 125/125 [01:36<00:00,  1.30it/s]
#                    all       2000       8130      0.763      0.607      0.696      0.461
# Speed: 0.2ms preprocess, 4.2ms inference, 0.0ms loss, 2.2ms postprocess per image
# ...

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/runs/detect/train4'
# !yolo task=segment mode=predict model='/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/runs/detect/train4/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/images/test' save=true
# Out:
# /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset_10k/runs/detect/train4
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1000 /content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/images/test/000000000074.jpg: 448x640 6 persons, 93.9ms
# image 2/1000 /content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/images/test/000000000308.jpg: 448x640 7 persons, 9.2ms
# image 3/1000 /content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/images/test/000000000370.jpg: 640x480 1 person, 63.1ms
# image 4/1000 /content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/images/test/000000000397.jpg: 480x640 1 person, 58.8ms
# ...

# %%
Image(filename=f'/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/runs/detect/train4/runs/detect/predict2/000000008746.jpg')

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset'

# !yolo detect train data='/content/drive/MyDrive/Project 2/yolo_v5-dataset/dataset.yaml' model='yolov8n.pt' epochs=30 imgsz=640 save=True batch=16

# %% [markdown]
# ## Comparation on Models
#
# > Add blockquote

# %%
# !yolo mode=val model='/content/drive/MyDrive/Project 2/yolo_v5-dataset/runs/detect/train4/weights/best.pt' data='/content/drive/MyDrive/Project 2/yolo_v5-test-dataset/dataset.yaml'
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-test-dataset/labels/val.cache... 500 images, 0 backgrounds, 0 corrupt: 100% 500/500 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 32/32 [00:12<00:00,  2.59it/s]
#                    all        500       1887      0.521      0.355      0.377      0.194
# Speed: 0.9ms preprocess, 6.8ms inference, 0.0ms loss, 4.5ms postprocess per image
# Results saved to runs/detect/val6
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo mode=val model='/content/drive/MyDrive/Project 2/yolo_v5-dataset/runs/detect/train6/weights/best.pt' data='/content/drive/MyDrive/Project 2/yolo_v5-test-dataset/dataset.yaml'
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-test-dataset/labels/val.cache... 500 images, 0 backgrounds, 0 corrupt: 100% 500/500 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 32/32 [00:15<00:00,  2.07it/s]
#                    all        500       1887      0.752      0.565      0.657      0.415
# Speed: 0.8ms preprocess, 7.7ms inference, 0.0ms loss, 5.0ms postprocess per image
# Results saved to runs/detect/val7
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-test-dataset'

# !yolo mode=val model='/content/drive/MyDrive/Project 2/yolo_v5-dataset_10k/runs/detect/train4/weights/best.pt' data='/content/drive/MyDrive/Project 2/yolo_v5-test-dataset/dataset.yaml'
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-test-dataset/labels/val... 500 images, 0 backgrounds, 0 corrupt: 100% 500/500 [01:57<00:00,  4.25it/s]
# val: New cache created: /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-test-dataset/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 32/32 [00:14<00:00,  2.16it/s]
#                    all        500       1887      0.826      0.645      0.752      0.518
# Speed: 0.9ms preprocess, 8.0ms inference, 0.0ms loss, 5.4ms postprocess per image
# Results saved to runs/detect/val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# %cd '/'
# %ls
# Out:
# /
# bin@                        datalab/  kaggle/  libx32@                   opt/   sbin@  tools/
# boot/                       dev/      lib@     media/                    proc/  srv/   usr/
# content/                    etc/      lib32@   mnt/                      root/  sys/   var/
# cuda-keyring_1.0-1_all.deb  home/     lib64@   NGC-DL-CONTAINER-LICENSE  run/   tmp/

# %%
model = YOLO('/home/insomnius/.pyenv/runs/detect/train11/weights/best.pt')

# video_path = './2863232-uhd_3840_2160_30fps.mp4'
video_path = './Shopping, People, Commerce, Mall, Many, Crowd, Walking   Free Stock video footage   YouTube.mp4'
# video_path = '8MP 4K Dahua CCTV System Sample Video - Night Time.mp4'

results = model.track(video_path, persist=True, stream=True, conf=0.25)

max_track_id = 0

cap = cv2.VideoCapture(video_path)
output = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*'MPEG'), 25, (int(cap.get(3)),int(cap.get(4))))

for result in results:
    summary = result.summary()
    for s in summary:
      if 'track_id' in s and 'name' in s and s['track_id'] > max_track_id and s['name'] == 'person':
        max_track_id = s['track_id']
    tracked_frame = result.plot()
    output.write(tracked_frame)
    cv2.imshow('frame', tracked_frame)
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

output.release()
cap.release()
cv2.destroyAllWindows()
print("Tracking video complete...")
print(f"There are {max_track_id} peoples in video")
