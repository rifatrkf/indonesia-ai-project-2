# %% [markdown]
# ## Install Ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.3/723.3 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 20.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.5 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.38 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Run inference on 'bus.jpg'
results = model(['/content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test/000000000086.jpg'])  # results list
results[0].plot()[..., ::-1]
# Out:
# 0: 640x512 1 person, 1 bicycle, 1 motorcycle, 118.9ms
# Speed: 20.1ms preprocess, 118.9ms inference, 853.1ms postprocess per image at shape (1, 3, 640, 512)
# array([[[203, 203, 203],
#         [204, 204, 204],
#         [220, 220, 220],
#         ...,
#         [ 66,  66,  66],
#         [ 61,  61,  61],
#         [ 53,  53,  53]],
#
#        [[197, 197, 197],
#         [188, 188, 188],
#         [196, 196, 196],
#         ...,
#         [ 54,  54,  54],
#         [ 49,  49,  49],
#         [ 39,  39,  39]],
#
#        [[191, 191, 191],
#         [169, 169, 169],
#         [164, 164, 164],
#         ...,
#         [ 50,  50,  50],
#         [ 48,  48,  48],
#         [ 39,  39,  39]],
#
#        ...,
#
#        [[127, 127, 127],
#         [139, 139, 139],
#         [184, 184, 184],
#         ...,
#         [ 80,  80,  80],
#         [ 86,  86,  86],
#         [ 86,  86,  86]],
#
#        [[239, 239, 239],
#         [246, 246, 246],
#         [253, 253, 253],
#         ...,
# ...

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset'

# !yolo detect train data='/content/drive/MyDrive/Project 2/yolo_v5-dataset/dataset.yaml' model='yolov8n.pt' epochs=30 imgsz=640 save=True batch=16
# Out:
# /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset
# Ultralytics YOLOv8.1.38 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/drive/MyDrive/Project 2/yolo_v5-dataset/runs/detect/train4/confusion_matrix.png', width=600)

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset'

# !yolo task=segment mode=val model='/content/drive/MyDrive/Project 2/yolo_v5-dataset/runs/detect/train4/weights/best.pt' data='/content/drive/MyDrive/Project 2/yolo_v5-dataset/dataset.yaml'
# Out:
# /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.1.38 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset/labels/val.cache... 200 images, 0 backgrounds, 0 corrupt: 100% 200/200 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:07<00:00,  1.79it/s]
#                    all        200        983      0.447      0.293      0.305      0.146
# Speed: 1.3ms preprocess, 11.0ms inference, 0.0ms loss, 5.7ms postprocess per image
# Results saved to runs/detect/val
# ...

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset/runs/detect/train4'
# !yolo task=segment mode=predict model='/content/drive/MyDrive/Project 2/yolo_v5-dataset/runs/detect/train4/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test' save=true
# Out:
# /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset/runs/detect/train4
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.1.38 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/400 /content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test/000000000036.jpg: 640x512 (no detections), 78.5ms
# image 2/400 /content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test/000000000049.jpg: 640x512 (no detections), 7.5ms
# image 3/400 /content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test/000000000061.jpg: 512x640 (no detections), 57.0ms
# image 4/400 /content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test/000000000086.jpg: 640x512 (no detections), 8.2ms
# ...
