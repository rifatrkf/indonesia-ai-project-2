# %% [markdown]
# ## Install Ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.7/744.7 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 44.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 48.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 54.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.9 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Load a pretrained YOLOv8n model
model = YOLO('/content/drive/MyDrive/Project 2/yolo_v5-dataset/yolov8n.pt')

# Run inference on 'bus.jpg'
results = model(['/content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test/000000000086.jpg'])  # results list
results[0].plot()[..., ::-1]
# Out:
# 0: 640x512 1 person, 1 bicycle, 1 motorcycle, 112.2ms
# Speed: 20.1ms preprocess, 112.2ms inference, 686.0ms postprocess per image at shape (1, 3, 640, 512)
# array([[[203, 203, 203],
#         [204, 204, 204],
#         [220, 220, 220],
#         ...,
#         [ 66,  66,  66],
#         [ 61,  61,  61],
#         [ 53,  53,  53]],
#
#        [[197, 197, 197],
#         [188, 188, 188],
#         [196, 196, 196],
#         ...,
#         [ 54,  54,  54],
#         [ 49,  49,  49],
#         [ 39,  39,  39]],
#
#        [[191, 191, 191],
#         [169, 169, 169],
#         [164, 164, 164],
#         ...,
#         [ 50,  50,  50],
#         [ 48,  48,  48],
#         [ 39,  39,  39]],
#
#        ...,
#
#        [[127, 127, 127],
#         [139, 139, 139],
#         [184, 184, 184],
#         ...,
#         [ 80,  80,  80],
#         [ 86,  86,  86],
#         [ 86,  86,  86]],
#
#        [[239, 239, 239],
#         [246, 246, 246],
#         [253, 253, 253],
#         ...,
# ...

# %%
import glob
export_dir = '/content/drive/MyDrive/Project 2/yolo_v5-dataset'
print(len(glob.glob(export_dir+"/images/train/*")))
print(len(glob.glob(export_dir+"/images/val/*")))
print(len(glob.glob(export_dir+"/images/test/*")))
# Out:
# 1400
# 400
# 200

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset'

# !yolo detect train data='/content/drive/MyDrive/Project 2/yolo_v5-dataset/dataset.yaml' model='yolov8n.pt' epochs=30 imgsz=640 save=True batch=16
# Out:
# /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/drive/MyDrive/Project 2/yolo_v5-dataset/runs/detect/train6/confusion_matrix.png', width=600)

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset'

# !yolo task=segment mode=val model='/content/drive/MyDrive/Project 2/yolo_v5-dataset/runs/detect/train6/weights/best.pt' data='/content/drive/MyDrive/Project 2/yolo_v5-dataset/dataset.yaml'
# Out:
# /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset/labels/val.cache... 400 images, 0 backgrounds, 0 corrupt: 100% 400/400 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:12<00:00,  1.99it/s]
#                    all        400       1638      0.707      0.552      0.633      0.391
# Speed: 1.2ms preprocess, 7.0ms inference, 0.0ms loss, 6.6ms postprocess per image
# Results saved to runs/detect/val2
# ...

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset/runs/detect/train6'
# !yolo task=segment mode=predict model='/content/drive/MyDrive/Project 2/yolo_v5-dataset/runs/detect/train6/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test' save=true
# Out:
# /content/drive/.shortcut-targets-by-id/1sHW6wbrYoqsjTlDxeexa-4LTQ-Qt76Gx/Project 2/yolo_v5-dataset/runs/detect/train6
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/200 /content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test/000000000074.jpg: 448x640 6 persons, 58.4ms
# image 2/200 /content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test/000000000136.jpg: 480x640 1 person, 91.4ms
# image 3/200 /content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test/000000000257.jpg: 480x640 21 persons, 13.1ms
# image 4/200 /content/drive/MyDrive/Project 2/yolo_v5-dataset/images/test/000000000328.jpg: 512x640 4 persons, 99.7ms
# ...

# %%
# %cd '/content/drive/MyDrive/Project 2/yolo_v5-dataset'

# !yolo detect train data='/content/drive/MyDrive/Project 2/yolo_v5-dataset/dataset.yaml' model='yolov8n.pt' epochs=30 imgsz=640 save=True batch=16
